# %%
# Instala la última versión compatible con CUDA (GPU)
# Se usa la versión base de PyTorch y se fuerza la actualización de torchvision
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Instala Real-ESRGAN y sus dependencias (basicsr)
# !pip install realesrgan

# Asegura que basicsr y sus dependencias (como numpy) estén actualizadas
# !pip install --upgrade basicsr numpy

# Reinicia el entorno de ejecución (Runtime) después de esta celda
print("⚠️ Por favor, ve a 'Entorno de ejecución' > 'Reiniciar entorno de ejecución' antes de continuar.")
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 66.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ...
